# %%
import pandas as pd

# %%
mydf= pd.read_csv("https://raw.githubusercontent.com/Colletaaliyah/jupyter-notebooks/main/csv%20files/sales_data_sample.csv" , sep=",",encoding='Latin-1', index_col=0)

# %%
mydf.head()
# Out:
#              QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERNUMBER
# 10107                     30      95.70                2  2871.00
# 10121                     34      81.35                5  2765.90
# 10134                     41      94.74                2  3884.34
# 10145                     45      83.26                6  3746.70
# 10159                     49     100.00               14  5205.27
#
#                    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  \
# ORDERNUMBER
# 10107         2/24/2003 0:00  Shipped       1         2     2003  Motorcycles
# 10121          5/7/2003 0:00  Shipped       2         5     2003  Motorcycles
# 10134          7/1/2003 0:00  Shipped       3         7     2003  Motorcycles
# 10145         8/25/2003 0:00  Shipped       3         8     2003  Motorcycles
# 10159        10/10/2003 0:00  Shipped       4        10     2003  Motorcycles
#
# ...

# %% [markdown]
# ## clean the column names

# %%
mydf.iloc[1]
# Out:
# QUANTITYORDERED                     34
# PRICEEACH                        81.35
# ORDERLINENUMBER                      5
# SALES                           2765.9
# ORDERDATE                5/7/2003 0:00
# STATUS                         Shipped
# QTR_ID                               2
# MONTH_ID                             5
# YEAR_ID                           2003
# PRODUCTLINE                Motorcycles
# MSRP                                95
# PRODUCTCODE                   S10_1678
# CUSTOMERNAME        Reims Collectables
# PHONE                       26.47.1555
# ADDRESSLINE1        59 rue de l'Abbaye
# ADDRESSLINE2                       NaN
# CITY                             Reims
# STATE                              NaN
# POSTALCODE                       51100
# COUNTRY                         France
# TERRITORY                         EMEA
# CONTACTLASTNAME                Henriot
# CONTACTFIRSTNAME                  Paul
# DEALSIZE                         Small
# ...

# %%
mydf.head(2)
# Out:
#              QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   SALES  \
# ORDERNUMBER
# 10107                     30      95.70                2  2871.0
# 10121                     34      81.35                5  2765.9
#
#                   ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  \
# ORDERNUMBER
# 10107        2/24/2003 0:00  Shipped       1         2     2003  Motorcycles
# 10121         5/7/2003 0:00  Shipped       2         5     2003  Motorcycles
#
#              ...             ADDRESSLINE1 ADDRESSLINE2   CITY STATE  \
# ORDERNUMBER  ...
# 10107        ...  897 Long Airport Avenue          NaN    NYC    NY
# 10121        ...       59 rue de l'Abbaye          NaN  Reims   NaN
#
#             POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  \
# ORDERNUMBER
# 10107            10022     USA       NaN              Yu             Kwai
# 10121            51100  France      EMEA         Henriot             Paul
#
#             DEALSIZE
# ORDERNUMBER
# ...

# %%
mydf.loc[10107, 'PRICEEACH']
# Out:
# ORDERNUMBER
# 10107     95.70
# 10107     99.91
# 10107    100.00
# 10107    100.00
# 10107     70.87
# 10107    100.00
# 10107     83.03
# 10107     92.90
# Name: PRICEEACH, dtype: float64

# %%
mydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2823 entries, 10107 to 10414
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   QUANTITYORDERED   2823 non-null   int64
#  1   PRICEEACH         2823 non-null   float64
#  2   ORDERLINENUMBER   2823 non-null   int64
#  3   SALES             2823 non-null   float64
#  4   ORDERDATE         2823 non-null   object
#  5   STATUS            2823 non-null   object
#  6   QTR_ID            2823 non-null   int64
#  7   MONTH_ID          2823 non-null   int64
#  8   YEAR_ID           2823 non-null   int64
#  9   PRODUCTLINE       2823 non-null   object
#  10  MSRP              2823 non-null   int64
#  11  PRODUCTCODE       2823 non-null   object
#  12  CUSTOMERNAME      2823 non-null   object
#  13  PHONE             2823 non-null   object
#  14  ADDRESSLINE1      2823 non-null   object
#  15  ADDRESSLINE2      302 non-null    object
# ...

# %%
mydf.shape
# Out:
# (2823, 24)

# %%
mydf.drop_duplicates(inplace= True, keep= False)

# %%
mydf.shape
# Out:
# (2823, 24)

# %%
mydf.columns
# Out:
# Index(['QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER', 'SALES', 'ORDERDATE',
#        'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID', 'PRODUCTLINE', 'MSRP',
#        'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'ADDRESSLINE2',
#        'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY',
#        'CONTACTLASTNAME', 'CONTACTFIRSTNAME', 'DEALSIZE'],
#       dtype='object')

# %%
mydf.columns= [col.lower() for col in mydf]
mydf.columns
# Out:
# Index(['quantityordered', 'priceeach', 'orderlinenumber', 'sales', 'orderdate',
#        'status', 'qtr_id', 'month_id', 'year_id', 'productline', 'msrp',
#        'productcode', 'customername', 'phone', 'addressline1', 'addressline2',
#        'city', 'state', 'postalcode', 'country', 'territory',
#        'contactlastname', 'contactfirstname', 'dealsize'],
#       dtype='object')

# %%
mydf.isnull()
# Out:
#              quantityordered  priceeach  orderlinenumber  sales  orderdate  \
# ORDERNUMBER
# 10107                  False      False            False  False      False
# 10121                  False      False            False  False      False
# 10134                  False      False            False  False      False
# 10145                  False      False            False  False      False
# 10159                  False      False            False  False      False
# ...                      ...        ...              ...    ...        ...
# 10350                  False      False            False  False      False
# 10373                  False      False            False  False      False
# 10386                  False      False            False  False      False
# 10397                  False      False            False  False      False
# 10414                  False      False            False  False      False
#
# ...

# %%
mydf.isnull().sum()
# Out:
# quantityordered        0
# priceeach              0
# orderlinenumber        0
# sales                  0
# orderdate              0
# status                 0
# qtr_id                 0
# month_id               0
# year_id                0
# productline            0
# msrp                   0
# productcode            0
# customername           0
# phone                  0
# addressline1           0
# addressline2        2521
# city                   0
# state               1486
# postalcode            76
# country                0
# territory           1074
# contactlastname        0
# contactfirstname       0
# dealsize               0
# dtype: int64

# %%
mydf.dropna(axis=1)
# Out:
#              quantityordered  priceeach  orderlinenumber    sales  \
# ORDERNUMBER
# 10107                     30      95.70                2  2871.00
# 10121                     34      81.35                5  2765.90
# 10134                     41      94.74                2  3884.34
# 10145                     45      83.26                6  3746.70
# 10159                     49     100.00               14  5205.27
# ...                      ...        ...              ...      ...
# 10350                     20     100.00               15  2244.40
# 10373                     29     100.00                1  3978.51
# 10386                     43     100.00                4  5417.57
# 10397                     34      62.24                1  2116.16
# 10414                     47      65.52                9  3079.44
#
#                    orderdate    status  qtr_id  month_id  year_id  \
# ORDERNUMBER
# 10107         2/24/2003 0:00   Shipped       1         2     2003
# ...

# %%
mydf.shape
# Out:
# (2823, 24)

# %% [markdown]
# ##imputation- address2= mydf[addressline2]
# with the null values fill using fillna(), ie; territory.fillna(territory_mean, inplace= True)

# %%
mydf.describe()
# Out:
#        quantityordered    priceeach  orderlinenumber         sales  \
# count      2823.000000  2823.000000      2823.000000   2823.000000
# mean         35.092809    83.658544         6.466171   3553.889072
# std           9.741443    20.174277         4.225841   1841.865106
# min           6.000000    26.880000         1.000000    482.130000
# 25%          27.000000    68.860000         3.000000   2203.430000
# 50%          35.000000    95.700000         6.000000   3184.800000
# 75%          43.000000   100.000000         9.000000   4508.000000
# max          97.000000   100.000000        18.000000  14082.800000
#
#             qtr_id     month_id     year_id         msrp
# count  2823.000000  2823.000000  2823.00000  2823.000000
# mean      2.717676     7.092455  2003.81509   100.715551
# std       1.203878     3.656633     0.69967    40.187912
# min       1.000000     1.000000  2003.00000    33.000000
# 25%       2.000000     4.000000  2003.00000    68.000000
# ...

# %%
mydf['priceeach'].describe()
# Out:
# count    2823.000000
# mean       83.658544
# std        20.174277
# min        26.880000
# 25%        68.860000
# 50%        95.700000
# 75%       100.000000
# max       100.000000
# Name: priceeach, dtype: float64

# %%
mydf['sales'].value_counts().head(10)
# Out:
# sales
# 3003.00    3
# 5464.69    2
# 2257.92    2
# 5004.80    2
# 2172.48    2
# 4948.20    2
# 2213.40    2
# 2441.04    2
# 3184.80    2
# 1463.00    2
# Name: count, dtype: int64

# %%
mydf.corr(numeric_only = True)
# Out:
#                  quantityordered  priceeach  orderlinenumber     sales  \
# quantityordered         1.000000   0.005564        -0.018397  0.551426
# priceeach               0.005564   1.000000        -0.020965  0.657841
# orderlinenumber        -0.018397  -0.020965         1.000000 -0.058400
# sales                   0.551426   0.657841        -0.058400  1.000000
# qtr_id                 -0.035323   0.008712         0.040716 -0.006796
# month_id               -0.039048   0.005152         0.034016 -0.009605
# year_id                 0.069535  -0.005938        -0.057367  0.035647
# msrp                    0.017881   0.670625        -0.021067  0.635239
#
#                    qtr_id  month_id   year_id      msrp
# quantityordered -0.035323 -0.039048  0.069535  0.017881
# priceeach        0.008712  0.005152 -0.005938  0.670625
# orderlinenumber  0.040716  0.034016 -0.057367 -0.021067
# sales           -0.006796 -0.009605  0.035647  0.635239
# ...

# %%
subset = mydf[['qtr_id', 'msrp']]

subset.head()
# Out:
#              qtr_id  msrp
# ORDERNUMBER
# 10107             1    95
# 10121             2    95
# 10134             3    95
# 10145             3    95
# 10159             4    95

# %%
set=mydf.iloc[1:5]
set
# Out:
#              quantityordered  priceeach  orderlinenumber    sales  \
# ORDERNUMBER
# 10121                     34      81.35                5  2765.90
# 10134                     41      94.74                2  3884.34
# 10145                     45      83.26                6  3746.70
# 10159                     49     100.00               14  5205.27
#
#                    orderdate   status  qtr_id  month_id  year_id  productline  \
# ORDERNUMBER
# 10121          5/7/2003 0:00  Shipped       2         5     2003  Motorcycles
# 10134          7/1/2003 0:00  Shipped       3         7     2003  Motorcycles
# 10145         8/25/2003 0:00  Shipped       3         8     2003  Motorcycles
# 10159        10/10/2003 0:00  Shipped       4        10     2003  Motorcycles
#
#              ...                   addressline1 addressline2           city  \
# ORDERNUMBER  ...
# 10121        ...             59 rue de l'Abbaye          NaN          Reims
# ...

# %%
mydf[(mydf['quantityordered'] >= 45) | (mydf['sales'] >= 3700)].head()
# Out:
#              quantityordered  priceeach  orderlinenumber    sales  \
# ORDERNUMBER
# 10134                     41      94.74                2  3884.34
# 10145                     45      83.26                6  3746.70
# 10159                     49     100.00               14  5205.27
# 10188                     48     100.00                1  5512.32
# 10211                     41     100.00               14  4708.44
#
#                    orderdate   status  qtr_id  month_id  year_id  productline  \
# ORDERNUMBER
# 10134          7/1/2003 0:00  Shipped       3         7     2003  Motorcycles
# 10145         8/25/2003 0:00  Shipped       3         8     2003  Motorcycles
# 10159        10/10/2003 0:00  Shipped       4        10     2003  Motorcycles
# 10188        11/18/2003 0:00  Shipped       4        11     2003  Motorcycles
# 10211         1/15/2004 0:00  Shipped       1         1     2004  Motorcycles
#
# ...

# %%
mydf[mydf['sales'].isin([5205.27, 4708.44])].head()
# Out:
#              quantityordered  priceeach  orderlinenumber    sales  \
# ORDERNUMBER
# 10159                     49      100.0               14  5205.27
# 10211                     41      100.0               14  4708.44
#
#                    orderdate   status  qtr_id  month_id  year_id  productline  \
# ORDERNUMBER
# 10159        10/10/2003 0:00  Shipped       4        10     2003  Motorcycles
# 10211         1/15/2004 0:00  Shipped       1         1     2004  Motorcycles
#
#              ...       addressline1 addressline2           city state  \
# ORDERNUMBER  ...
# 10159        ...    7734 Strong St.          NaN  San Francisco    CA
# 10211        ...  25, rue Lauriston          NaN          Paris   NaN
#
#             postalcode country territory contactlastname contactfirstname  \
# ORDERNUMBER
# 10159              NaN     USA       NaN           Brown            Julie
# 10211            75016  France      EMEA         Perrier        Dominique
#
#             dealsize
# ...

# %%
mydf[
    ((mydf['priceeach'] >= 100) & (mydf['sales'] <= 6000))
    & (mydf['productline'] == 'motorcycles')
    & (mydf['priceeach'] > mydf['priceeach'].quantile(0.25))
]
# Out:
# Empty DataFrame
# Columns: [quantityordered, priceeach, orderlinenumber, sales, orderdate, status, qtr_id, month_id, year_id, productline, msrp, productcode, customername, phone, addressline1, addressline2, city, state, postalcode, country, territory, contactlastname, contactfirstname, dealsize]
# Index: []
#
# [0 rows x 24 columns]
