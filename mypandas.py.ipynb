# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pip install xlrd
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#      -------------------------------- ----- 81.9/96.5 kB 573.4 kB/s eta 0:00:01
#      -------------------------------- ----- 81.9/96.5 kB 573.4 kB/s eta 0:00:01
#      -------------------------------------- 96.5/96.5 kB 459.0 kB/s eta 0:00:00
# ...

# %%
pd.read_excel(r"C:\Users\admin\OneDrive\Documents\excel tasks\Analysis 1.xlsx")
# Out:
#           Unnamed: 0     Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                NaN            NaN         NaN         NaN         NaN
# 1                NaN            NaN         NaN         NaN         NaN
# 2   Average of marks  Column Labels         NaN         NaN         NaN
# 3         Row Labels     02/06/2016  05/06/2016  10/06/2016  15/06/2016
# 4            Biology            NaN   47.894737         NaN         NaN
# 5          Chemistry            NaN         NaN         NaN   52.407407
# 6        Mathematics            NaN         NaN         NaN         NaN
# 7         Philosophy      46.789474         NaN         NaN         NaN
# 8            Physics            NaN         NaN   51.761905         NaN
# 9          Sociology            NaN         NaN         NaN         NaN
# 10       Grand Total      46.789474   47.894737   51.761905   52.407407
#
#     Unnamed: 5  Unnamed: 6   Unnamed: 7
# 0          NaN         NaN          NaN
# ...

# %%
pd.read_excel(r"C:\Users\admin\OneDrive\Documents\excel tasks\Analysis.xlsx")
# Out:
#              student    subject        date  marks Grade  Column1
# 0       James Walker    Biology  05/06/2016     31     E      6.2
# 1      Velma Clemons    Biology  05/06/2016     43     D      8.6
# 2     Kibo Underwood    Biology  05/06/2016     81     A     16.2
# 3        Louis Mcgee    Biology  05/06/2016     11     E      2.2
# 4       Phyllis Paul    Biology  05/06/2016     18     E      3.6
# ..               ...        ...         ...    ...   ...      ...
# 195       Yen Bowers  Sociology  21/06/2016     52     C     10.4
# 196        Ryan Pena  Sociology  21/06/2016     16     E      3.2
# 197  Portia Hamilton  Sociology  21/06/2016     34     E      6.8
# 198  Sydnee Chambers  Sociology  21/06/2016     76     B     15.2
# 199      Stacy Small  Sociology  21/06/2016     96     A     19.2
#
# [200 rows x 6 columns]
